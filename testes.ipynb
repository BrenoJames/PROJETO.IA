# %%
# Aqui você cola os dados das pizzas que você me mandou
from turtle import pd


dados = {
    'diametro': [30, 31, 32, 33, 34, 36, 37, 38, 39, 40, 41, 42],
    'preco': [23, 25, 27, 29, 31, 33, 36, 39, 41, 44, 46, 50]
}
df = pd.DataFrame(dados)
df.head() # Exibe as primeiras linhas para conferir
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 9
#       5 dados = {
#       6     'diametro': [30, 31, 32, 33, 34, 36, 37, 38, 39, 40, 41, 42],
#       7     'preco': [23, 25, 27, 29, 31, 33, 36, 39, 41, 44, 46, 50]
#       8 }
# ----> 9 df = pd.DataFrame(dados)
#      10 df.head() # Exibe as primeiras linhas para conferir
#
# AttributeError: 'function' object has no attribute 'DataFrame'

# %%
modelo = LinearRegression()
X = df[['diametro']]
y = df['preco']
modelo.fit(X, y)

print("IA Treinada!")
# Out:
# IA Treinada!
