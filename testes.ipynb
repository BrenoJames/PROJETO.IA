# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt # Ótimo para ver o gráfico no Notebook

# %%
# Aqui você cola os dados das pizzas que você me mandou
dados = {
    'diametro': [30, 31, 32, 33, 34, 36, 37, 38, 39, 40, 41, 42],
    'preco': [23, 25, 27, 29, 31, 33, 36, 39, 41, 44, 46, 50]
}
df = pd.DataFrame(dados)
df.head() # Exibe as primeiras linhas para conferir
# Out:
#    diametro  preco
# 0        30     23
# 1        31     25
# 2        32     27
# 3        33     29
# 4        34     31

# %%
modelo = LinearRegression()
X = df[['diametro']]
y = df['preco']
modelo.fit(X, y)

print("IA Treinada!")
# Out:
# IA Treinada!
